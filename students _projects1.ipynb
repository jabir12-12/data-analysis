# %% [markdown]
# # datasets for students performance in exam

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv(r"C:\Users\lenovo\OneDrive\Desktop\StudentsPerformance.csv")
data
# Out:
#      gender     race parentallevelofeducation         lunch  \
# 0    female  group B        bachelor's degree      standard
# 1    female  group C             some college      standard
# 2    female  group B          master's degree      standard
# 3      male  group A       associate's degree  free/reduced
# 4      male  group C             some college      standard
# ..      ...      ...                      ...           ...
# 995  female  group E          master's degree      standard
# 996    male  group C              high school  free/reduced
# 997  female  group C              high school  free/reduced
# 998  female  group D             some college      standard
# 999  female  group D             some college  free/reduced
#
#     testpreparationcourse  mathscore  readingscore  writingscore
# 0                    none         72            72            74
# 1               completed         69            90            88
# ...

# %%
data.dtypes
# Out:
# gender                      object
# race                        object
# parentallevelofeducation    object
# lunch                       object
# testpreparationcourse       object
# mathscore                    int64
# readingscore                 int64
# writingscore                 int64
# dtype: object

# %%
data.count()
# Out:
# gender                      1000
# race                        1000
# parentallevelofeducation    1000
# lunch                       1000
# testpreparationcourse       1000
# mathscore                   1000
# readingscore                1000
# writingscore                1000
# dtype: int64

# %%
data.isnull().sum()
# Out:
# gender                      0
# race                        0
# parentallevelofeducation    0
# lunch                       0
# testpreparationcourse       0
# mathscore                   0
# readingscore                0
# writingscore                0
# dtype: int64

# %%
data[data.gender=='male']
# Out:
#     gender     race parentallevelofeducation         lunch  \
# 0     male  group B        bachelor's degree      standard
# 1     male  group C             some college      standard
# 2     male  group B          master's degree      standard
# 3     male  group A       associate's degree  free/reduced
# 4     male  group C             some college      standard
# ..     ...      ...                      ...           ...
# 995   male  group E          master's degree      standard
# 996   male  group C              high school  free/reduced
# 997   male  group C              high school  free/reduced
# 998   male  group D             some college      standard
# 999   male  group D             some college  free/reduced
#
#     testpreparationcourse  mathscore  readingscore  writingscore
# 0                    none         72            72            74
# 1               completed         69            90            88
# ...

# %%
[data.gender=='female']
# Out:
# [0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  995    False
#  996    False
#  997    False
#  998    False
#  999    False
#  Name: gender, Length: 1000, dtype: bool]

# %%
data.lunch.value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
data.testpreparationcourse.value_counts()
# Out:
# testpreparationcourse
# none         642
# completed    358
# Name: count, dtype: int64

# %% [markdown]
# # top scorer of exam

# %%
data.groupby('gender').max()
# Out:
#            race parentallevelofeducation     lunch testpreparationcourse  \
# gender
# female  group E         some high school  standard                  none
# male    group E         some high school  standard                  none
#
#         mathscore  readingscore  writingscore
# gender
# female        100           100           100
# male          100           100           100

# %% [markdown]
# # students who got lowest marks in exam

# %%
data.groupby("gender").min()
# Out:
#            race parentallevelofeducation         lunch testpreparationcourse  \
# gender
# female  group A       associate's degree  free/reduced             completed
# male    group A       associate's degree  free/reduced             completed
#
#         mathscore  readingscore  writingscore
# gender
# female          0            17            10
# male           27            23            15

# %% [markdown]
# #   students  who got distinction in each subject

# %%
len(data[(data.mathscore > 85)&(data.writingscore > 85)&(data.readingscore > 85)])
# Out:
# 51

# %%
fd=data[(data.mathscore > 85)&(data.writingscore > 85)&(data.readingscore > 85)]
fd
# Out:
#      gender     race parentallevelofeducation         lunch  \
# 2    female  group B          master's degree      standard
# 6    female  group B             some college      standard
# 16     male  group C              high school      standard
# 104    male  group C             some college      standard
# 106  female  group D          master's degree      standard
# 114  female  group E        bachelor's degree      standard
# 121    male  group B       associate's degree      standard
# 122  female  group C             some college      standard
# 125  female  group B              high school      standard
# 149    male  group E       associate's degree  free/reduced
# 165  female  group C        bachelor's degree      standard
# 179  female  group D         some high school      standard
# 229  female  group C             some college      standard
# 263  female  group E              high school      standard
# 268  female  group D       associate's degree      standard
# ...

# %% [markdown]
# #   students who got first class marks in each subjects

# %%
data[(data.mathscore > 60)&(data.mathscore <=85 )&(data.writingscore > 60)&(data.writingscore <=85)&(data.readingscore  > 60)&(data.readingscore<=85)]
# Out:
#      gender     race parentallevelofeducation         lunch  \
# 0    female  group B        bachelor's degree      standard
# 4      male  group C             some college      standard
# 5    female  group B       associate's degree      standard
# 8      male  group D              high school  free/reduced
# 12   female  group B              high school      standard
# ..      ...      ...                      ...           ...
# 987    male  group E         some high school      standard
# 991  female  group B         some high school      standard
# 993  female  group D        bachelor's degree  free/reduced
# 994    male  group A              high school      standard
# 998  female  group D             some college      standard
#
#     testpreparationcourse  mathscore  readingscore  writingscore
# 0                    none         72            72            74
# 4                    none         76            78            75
# ...

# %% [markdown]
# #   students who got second class marks in each subjects

# %%
data[(data.mathscore > 40)&(data.mathscore <=60 )&(data.writingscore > 40)&(data.writingscore <=60)&(data.readingscore  > 40)&(data.readingscore<=60)]
# Out:
#      gender     race parentallevelofeducation         lunch  \
# 3      male  group A       associate's degree  free/reduced
# 10     male  group C       associate's degree      standard
# 14   female  group A          master's degree      standard
# 18     male  group C          master's degree  free/reduced
# 22     male  group D             some college      standard
# ..      ...      ...                      ...           ...
# 961  female  group D         some high school  free/reduced
# 972  female  group A              high school  free/reduced
# 978    male  group D              high school      standard
# 985    male  group A              high school      standard
# 988  female  group A         some high school  free/reduced
#
#     testpreparationcourse  mathscore  readingscore  writingscore
# 3                    none         47            57            44
# 10                   none         58            54            52
# ...

# %% [markdown]
# #   students who failed in exam

# %%
len(data[(data.mathscore <35)&(data.writingscore <35)&(data.readingscore < 35)])
# Out:
# 8

# %%
data[(data.mathscore <35)&(data.writingscore <35)&(data.readingscore < 35)]
# Out:
#      gender     race parentallevelofeducation         lunch  \
# 17   female  group B         some high school  free/reduced
# 59   female  group C         some high school  free/reduced
# 76     male  group E         some high school      standard
# 327    male  group A             some college  free/reduced
# 363  female  group D         some high school  free/reduced
# 596    male  group B              high school  free/reduced
# 601  female  group C              high school      standard
# 980  female  group B              high school  free/reduced
#
#     testpreparationcourse  mathscore  readingscore  writingscore
# 17                   none         18            32            28
# 59                   none          0            17            10
# 76                   none         30            26            22
# 327                  none         28            23            19
# 363                  none         27            34            32
# ...

# %%
data.head()
# Out:
#    gender     race parentallevelofeducation         lunch  \
# 0  female  group B        bachelor's degree      standard
# 1  female  group C             some college      standard
# 2  female  group B          master's degree      standard
# 3    male  group A       associate's degree  free/reduced
# 4    male  group C             some college      standard
#
#   testpreparationcourse  mathscore  readingscore  writingscore
# 0                  none         72            72            74
# 1             completed         69            90            88
# 2                  none         90            95            93
# 3                  none         47            57            44
# 4                  none         76            78            75

# %%
data.race.value_counts()
# Out:
# race
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %% [markdown]
# # arranging race on basis on groups

# %%
data[data['race'].isin(["group A"])]
# Out:
#      gender     race parentallevelofeducation         lunch  \
# 3      male  group A       associate's degree  free/reduced
# 13     male  group A             some college      standard
# 14   female  group A          master's degree      standard
# 25     male  group A          master's degree  free/reduced
# 46   female  group A       associate's degree      standard
# ..      ...      ...                      ...           ...
# 974  female  group A             some college      standard
# 983  female  group A             some college      standard
# 985    male  group A              high school      standard
# 988  female  group A         some high school  free/reduced
# 994    male  group A              high school      standard
#
#     testpreparationcourse  mathscore  readingscore  writingscore
# 3                    none         47            57            44
# 13              completed         78            72            70
# ...

# %%
data[data['race'].isin(["group B"])]
# Out:
#      gender     race parentallevelofeducation         lunch  \
# 0    female  group B        bachelor's degree      standard
# 2    female  group B          master's degree      standard
# 5    female  group B       associate's degree      standard
# 6    female  group B             some college      standard
# 7      male  group B             some college  free/reduced
# ..      ...      ...                      ...           ...
# 969  female  group B        bachelor's degree      standard
# 976    male  group B             some college  free/reduced
# 980  female  group B              high school  free/reduced
# 982    male  group B         some high school      standard
# 991  female  group B         some high school      standard
#
#     testpreparationcourse  mathscore  readingscore  writingscore
# 0                    none         72            72            74
# 2                    none         90            95            93
# ...

# %%
data[data['race'].isin(["group C"])]
# Out:
#      gender     race parentallevelofeducation         lunch  \
# 1    female  group C             some college      standard
# 4      male  group C             some college      standard
# 10     male  group C       associate's degree      standard
# 15   female  group C         some high school      standard
# 16     male  group C              high school      standard
# ..      ...      ...                      ...           ...
# 979  female  group C       associate's degree      standard
# 984  female  group C         some high school      standard
# 986  female  group C       associate's degree      standard
# 996    male  group C              high school  free/reduced
# 997  female  group C              high school  free/reduced
#
#     testpreparationcourse  mathscore  readingscore  writingscore
# 1               completed         69            90            88
# 4                    none         76            78            75
# ...

# %%
data[data['race'].isin(["group C"])]
# Out:
#      gender     race parentallevelofeducation         lunch  \
# 1    female  group C             some college      standard
# 4      male  group C             some college      standard
# 10     male  group C       associate's degree      standard
# 15   female  group C         some high school      standard
# 16     male  group C              high school      standard
# ..      ...      ...                      ...           ...
# 979  female  group C       associate's degree      standard
# 984  female  group C         some high school      standard
# 986  female  group C       associate's degree      standard
# 996    male  group C              high school  free/reduced
# 997  female  group C              high school  free/reduced
#
#     testpreparationcourse  mathscore  readingscore  writingscore
# 1               completed         69            90            88
# 4                    none         76            78            75
# ...

# %%
data[data['race'].isin(["group D"])]
# Out:
#      gender     race parentallevelofeducation         lunch  \
# 8      male  group D              high school  free/reduced
# 11     male  group D       associate's degree      standard
# 20     male  group D              high school      standard
# 22     male  group D             some college      standard
# 24     male  group D        bachelor's degree  free/reduced
# ..      ...      ...                      ...           ...
# 989  female  group D             some college  free/reduced
# 992  female  group D       associate's degree  free/reduced
# 993  female  group D        bachelor's degree  free/reduced
# 998  female  group D             some college      standard
# 999  female  group D             some college  free/reduced
#
#     testpreparationcourse  mathscore  readingscore  writingscore
# 8               completed         64            64            67
# 11                   none         40            52            43
# ...

# %%
data[data['race'].isin(["group E"])]
# Out:
#      gender     race parentallevelofeducation         lunch  \
# 32   female  group E          master's degree  free/reduced
# 34     male  group E             some college      standard
# 35     male  group E       associate's degree      standard
# 44   female  group E       associate's degree  free/reduced
# 50     male  group E             some college      standard
# ..      ...      ...                      ...           ...
# 962  female  group E       associate's degree      standard
# 968  female  group E       associate's degree      standard
# 987    male  group E         some high school      standard
# 990    male  group E              high school  free/reduced
# 995  female  group E          master's degree      standard
#
#     testpreparationcourse  mathscore  readingscore  writingscore
# 32                   none         56            72            65
# 34                   none         97            87            82
# ...

# %%
data.parentallevelofeducation.value_counts()
# Out:
# parentallevelofeducation
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %% [markdown]
# # the qualification of parent who have master degree

# %%
len(data[data.parentallevelofeducation=="master's degree"])
# Out:
# 59

# %%
data[data.parentallevelofeducation=="master's degree"]
# Out:
#      gender     race parentallevelofeducation         lunch  \
# 2    female  group B          master's degree      standard
# 14   female  group A          master's degree      standard
# 18     male  group C          master's degree  free/reduced
# 25     male  group A          master's degree  free/reduced
# 29   female  group D          master's degree      standard
# 32   female  group E          master's degree  free/reduced
# 79   female  group E          master's degree      standard
# 106  female  group D          master's degree      standard
# 128    male  group D          master's degree      standard
# 130    male  group D          master's degree      standard
# 162    male  group B          master's degree  free/reduced
# 164  female  group E          master's degree      standard
# 167  female  group B          master's degree  free/reduced
# 175  female  group C          master's degree      standard
# 178  female  group B          master's degree  free/reduced
# ...

# %%
data.head()
# Out:
#    gender     race parentallevelofeducation         lunch  \
# 0  female  group B        bachelor's degree      standard
# 1  female  group C             some college      standard
# 2  female  group B          master's degree      standard
# 3    male  group A       associate's degree  free/reduced
# 4    male  group C             some college      standard
#
#   testpreparationcourse  mathscore  readingscore  writingscore
# 0                  none         72            72            74
# 1             completed         69            90            88
# 2                  none         90            95            93
# 3                  none         47            57            44
# 4                  none         76            78            75

# %%
# visual reprenstaion of parents qualification

# %%
plt.figure(figsize=(18,7))
sns.countplot(x='parentallevelofeducation',hue='parentallevelofeducation',data=data)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.show()

# %%
data.head()
# Out:
#    gender     race parentallevelofeducation         lunch  \
# 0  female  group B        bachelor's degree      standard
# 1  female  group C             some college      standard
# 2  female  group B          master's degree      standard
# 3    male  group A       associate's degree  free/reduced
# 4    male  group C             some college      standard
#
#   testpreparationcourse  mathscore  readingscore  writingscore
# 0                  none         72            72            74
# 1             completed         69            90            88
# 2                  none         90            95            93
# 3                  none         47            57            44
# 4                  none         76            78            75

# %%
sns.displot(data=data,x='race',hue='race')
# Out:
# C:\Windows\New folder\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
data.head()
# Out:
#    gender     race parentallevelofeducation         lunch  \
# 0  female  group B        bachelor's degree      standard
# 1  female  group C             some college      standard
# 2  female  group B          master's degree      standard
# 3    male  group A       associate's degree  free/reduced
# 4    male  group C             some college      standard
#
#   testpreparationcourse  mathscore  readingscore  writingscore
# 0                  none         72            72            74
# 1             completed         69            90            88
# 2                  none         90            95            93
# 3                  none         47            57            44
# 4                  none         76            78            75

# %%
sns.displot(x='gender',hue='gender',data=data)
plt.xlabel('sex')
# Out:
# C:\Windows\New folder\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(0.5, 9.444444444444438, 'sex')
